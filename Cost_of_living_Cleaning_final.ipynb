# %% [markdown]
# # Cost of Living
#
#
# https://www.kaggle.com/datasets/mvieira101/global-cost-of-living
#
#
# - city	Name of the city
# - country	Name of the country
# - x1	Meal, Inexpensive Restaurant (USD)
# - x2	Meal for 2 People, Mid-range Restaurant, Three-course (USD)
# - x3	McMeal at McDonalds (or Equivalent Combo Meal) (USD)
# - x4	Domestic Beer (0.5 liter draught, in restaurants) (USD)
# - x5	Imported Beer (0.33 liter bottle, in restaurants) (USD)
# - x6	Cappuccino (regular, in restaurants) (USD)
# - x7	Coke/Pepsi (0.33 liter bottle, in restaurants) (USD)
# - x8	Water (0.33 liter bottle, in restaurants) (USD)
# - x9	Milk (regular), (1 liter) (USD)
# - x10	Loaf of Fresh White Bread (500g) (USD)
# - x11	Rice (white), (1kg) (USD)
# - x12	Eggs (regular) (12) (USD)
# - x13	Local Cheese (1kg) (USD)
# - x14	Chicken Fillets (1kg) (USD)
# - x15	Beef Round (1kg) (or Equivalent Back Leg Red Meat) (USD)
# - x16	Apples (1kg) (USD)
# - x17	Banana (1kg) (USD)
# - x18	Oranges (1kg) (USD)
# - x19	Tomato (1kg) (USD)
# - x20	Potato (1kg) (USD)
# - x21	Onion (1kg) (USD)
# - x22	Lettuce (1 head) (USD)
# - x23	Water (1.5 liter bottle, at the market) (USD)
# - x24	Bottle of Wine (Mid-Range, at the market) (USD)
# - x25	Domestic Beer (0.5 liter bottle, at the market) (USD)
# - x26	Imported Beer (0.33 liter bottle, at the market) (USD)
# - x27	Cigarettes 20 Pack (Marlboro) (USD)
# - x28	One-way Ticket (Local Transport) (USD)
# - x29	Monthly Pass (Regular Price) (USD)
# - x30	Taxi Start (Normal Tariff) (USD)
# - x31	Taxi 1km (Normal Tariff) (USD)
# - x32	Taxi 1hour Waiting (Normal Tariff) (USD)
# - x33	Gasoline (1 liter) (USD)
# - x34	Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car) (USD)
# - x35	Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car) (USD)
# - x36	Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment (USD)
# - x37	1 min. of Prepaid Mobile Tariff Local (No Discounts or Plans) (USD)
# - x38	Internet (60 Mbps or More, Unlimited Data, Cable/ADSL) (USD)
# - x39	Fitness Club, Monthly Fee for 1 Adult (USD)
# - x40	Tennis Court Rent (1 Hour on Weekend) (USD)
# - x41	Cinema, International Release, 1 Seat (USD)
# - x42	Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child (USD)
# - x43	International Primary School, Yearly for 1 Child (USD)
# - x44	1 Pair of Jeans (Levis 501 Or Similar) (USD)
# - x45	1 Summer Dress in a Chain Store (Zara, H&M, …) (USD)
# - x46	1 Pair of Nike Running Shoes (Mid-Range) (USD)
# - x47	1 Pair of Men Leather Business Shoes (USD)
# - x48	Apartment (1 bedroom) in City Centre (USD)
# - x49	Apartment (1 bedroom) Outside of Centre (USD)
# - x50	Apartment (3 bedrooms) in City Centre (USD)
# - x51	Apartment (3 bedrooms) Outside of Centre (USD)
# - x52	Price per Square Meter to Buy Apartment in City Centre (USD)
# - x53	Price per Square Meter to Buy Apartment Outside of Centre (USD)
# - x54	Average Monthly Net Salary (After Tax) (USD)
# - x55	Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# - data_quality	0 if Numbeo considers that more contributors are needed to increase data quality, else 1

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Load dataset from an csv file

cost = pd.read_csv('cost-of-living.csv')
cost
# Out:
#       Unnamed: 0                city      country     x1     x2     x3     x4  \
# 0              0               Delhi        India   4.90  22.04   4.28   1.84
# 1              1            Shanghai        China   5.59  40.51   5.59   1.12
# 2              2             Jakarta    Indonesia   2.54  22.25   3.50   2.02
# 3              3              Manila  Philippines   3.54  27.40   3.54   1.24
# 4              4               Seoul  South Korea   7.16  52.77   6.03   3.02
# ...          ...                 ...          ...    ...    ...    ...    ...
# 4869        4869        Peterborough    Australia    NaN    NaN    NaN    NaN
# 4870        4870          Georgetown    Australia    NaN    NaN    NaN    NaN
# 4871        4871  Ixtapa Zihuatanejo       Mexico   5.19  31.13  12.97   0.99
# 4872        4872             Iqaluit       Canada  29.78  74.61  13.77   6.70
# 4873        4873              Neiafu        Tonga    NaN  29.53  10.55  10.55
#
# ...

# %%
# Original columns from the dataset
cost.columns
# Out:
# Index(['Unnamed: 0', 'city', 'country', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6',
#        'x7', 'x8', 'x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16',
#        'x17', 'x18', 'x19', 'x20', 'x21', 'x22', 'x23', 'x24', 'x25', 'x26',
#        'x27', 'x28', 'x29', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x36',
#        'x37', 'x38', 'x39', 'x40', 'x41', 'x42', 'x43', 'x44', 'x45', 'x46',
#        'x47', 'x48', 'x49', 'x50', 'x51', 'x52', 'x53', 'x54', 'x55',
#        'data_quality'],
#       dtype='object')

# %%
# dropping columns that we consider not relevant such as Cigarettes, Taxi, Mortgage...  
cost.drop(['Unnamed: 0','x27', 'x28', 'x30', 'x31', 'x32', 'x33', 'x34', 'x35', 'x37', 'x40', 'x43', 'x55', 'data_quality'], axis=1, inplace=True)

# %%
### Restaurants 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8'

cost['restaurant'] = cost[['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8']].mean(axis=1)
cost.drop(['x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8'], axis= 1, inplace= True)

# %%
### Groceries x9, x10, x11, x12, x13, x14, x15, x16, x17, x18, x19, x20, x21, x22, x23, x24, x25, x26

cost['groceries'] = cost[['x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20',
                         'x21', 'x22', 'x23', 'x24', 'x25', 'x26']].sum(axis=1)
cost.drop(['x9', 'x10', 'x11', 'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20',
                         'x21', 'x22', 'x23', 'x24', 'x25', 'x26'], axis= 1, inplace= True)

# %%
### Transport x29

cost['transport'] = cost[['x29']].mean(axis=1)
cost.drop(['x29'], axis= 1, inplace = True)

# %%
### Freetime x39, x41

cost['freetime'] = cost[['x39', 'x41']].mean(axis=1)
cost.drop(['x39', 'x41'], axis= 1, inplace = True)

# %%
### Utilities x36, x38

cost['utilities'] = cost[['x36', 'x38']].sum(axis=1)
cost.drop(['x36', 'x38'], axis= 1, inplace = True)

# %%
### Childcare x42

cost['childcare'] = cost['x42']
cost.drop(['x42'], axis= 1, inplace = True)

# %%
### Clothing

cost['clothing'] = cost[['x44', 'x45', 'x46','x47']].mean(axis=1)
cost.drop(['x44', 'x45', 'x46','x47'], axis= 1, inplace = True)

# %%
### Rent x48, x49, x50, x51

cost['rent'] = cost[['x48', 'x49', 'x50', 'x51']].mean(axis=1)
cost.drop(['x48', 'x49', 'x50', 'x51'], axis= 1, inplace= True)

# %%
### Rent x52, x53

cost['housing_price'] = cost[['x52', 'x53']].mean(axis=1)
cost.drop(['x52', 'x53'], axis= 1, inplace= True)

# %%
### Renaming the column x54 

cost['average_salary'] = cost['x54']
cost.drop(['x54'], axis= 1, inplace = True)

# %%
cost
# Out:
#                     city      country  restaurant  groceries  transport  \
# 0                  Delhi        India    4.897500      36.63      11.63
# 1               Shanghai        China    7.725000      71.51      27.94
# 2                Jakarta    Indonesia    4.567500      62.00       9.53
# 3                 Manila  Philippines    5.246250      46.84      11.86
# 4                  Seoul  South Korea    9.950000     127.80      41.47
# ...                  ...          ...         ...        ...        ...
# 4869        Peterborough    Australia         NaN       0.00        NaN
# 4870          Georgetown    Australia         NaN       0.00        NaN
# 4871  Ixtapa Zihuatanejo       Mexico    7.591429       4.63        NaN
# 4872             Iqaluit       Canada   18.143750      98.29        NaN
# 4873              Neiafu        Tonga   10.970000      36.66        NaN
#
#       freetime  utilities  childcare  clothing       rent  housing_price  \
# ...

# %%
cost.describe()
# Out:
#         restaurant    groceries    transport     freetime      utilities  \
# count  4671.000000  4874.000000  2750.000000  4509.000000    4874.000000
# mean      9.063629    56.264471    43.832596    19.710401     258.152517
# std       5.274900    28.327713    36.519276    13.386897    6965.566145
# min       0.285000     0.000000     0.000000     0.000000       0.000000
# 25%       4.795208    36.890000    17.915000    10.615000      75.007500
# 50%       8.351250    53.005000    35.320000    18.135000     153.060000
# 75%      12.591250    74.970000    60.060000    25.405000     226.965000
# max      80.000000   216.790000   364.580000   277.855000  486397.870000
#
#          childcare     clothing          rent  housing_price  average_salary
# count  3761.000000  4502.000000   3800.000000    2800.000000     3459.000000
# mean    488.987812    62.263380    876.937496    2768.288495     1817.033501
# std     514.976064    23.631437    806.932604    4667.701858     1626.482870
# ...

# %% [markdown]
# #######################################################################################################################

# %%
# Check for null values in each column
cost.isnull().sum()
# Out:
# city                 0
# country              0
# restaurant         203
# groceries            0
# transport         2124
# freetime           365
# utilities            0
# childcare         1113
# clothing           372
# rent              1074
# housing_price     2074
# average_salary    1415
# dtype: int64

# %%
cost[cost['city'] == 'Neiafu'].isnull().sum()
# Out:
# city              0
# country           0
# restaurant        0
# groceries         0
# transport         1
# freetime          1
# utilities         0
# childcare         1
# clothing          1
# rent              1
# housing_price     1
# average_salary    1
# dtype: int64

# %%
grouped_by_country = cost.groupby('country')

# Check for null values in each group
null_values_by_country = pd.DataFrame(grouped_by_country.apply(lambda x: x.isnull().sum()))

# Display the result
null_values_by_country
# Out:
#                 city  country  restaurant  groceries  transport  freetime  \
# country
# Afghanistan        0        0           2          0          3         2
# Albania            0        0           0          0          5         2
# Algeria            0        0           1          0         16         1
# American Samoa     0        0           0          0          1         1
# Andorra            0        0           0          0          0         0
# ...              ...      ...         ...        ...        ...       ...
# Venezuela          0        0           1          0         11         1
# Vietnam            0        0           4          0         14         2
# Yemen              0        0           1          0          6         5
# Zambia             0        0           2          0          5         3
# Zimbabwe           0        0           2          0          8         2
#
#                 utilities  childcare  clothing  rent  housing_price  \
# ...

# %%
cost.dropna(thresh=6, inplace=True)

# %%
cost
# Out:
#                     city      country  restaurant  groceries  transport  \
# 0                  Delhi        India    4.897500      36.63      11.63
# 1               Shanghai        China    7.725000      71.51      27.94
# 2                Jakarta    Indonesia    4.567500      62.00       9.53
# 3                 Manila  Philippines    5.246250      46.84      11.86
# 4                  Seoul  South Korea    9.950000     127.80      41.47
# ...                  ...          ...         ...        ...        ...
# 4864        Port Douglas    Australia   13.796250     100.61        NaN
# 4865         Rockhampton    Australia   12.638750      68.43      90.53
# 4867        Egilsstadhir      Iceland   13.910000      91.46      52.96
# 4871  Ixtapa Zihuatanejo       Mexico    7.591429       4.63        NaN
# 4872             Iqaluit       Canada   18.143750      98.29        NaN
#
#       freetime  utilities  childcare  clothing       rent  housing_price  \
# ...

# %%
country_means = cost.groupby('country').mean()
# Out:
# /var/folders/1x/nk1pmjs57kd0k7pp1vkgtk7w0000gn/T/ipykernel_57165/3346768192.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   country_means = cost.groupby('country').mean()

# %%
country_means
# Out:
#                 restaurant  groceries  transport   freetime   utilities  \
# country
# Afghanistan       2.083452  20.852500  13.333333   7.025000  336.620000
# Albania           4.934917  36.047333  11.899000  14.172692   94.336000
# Algeria           2.874448  36.913333   9.819412  10.426250   67.163333
# American Samoa    7.482500  37.410000        NaN        NaN   79.980000
# Andorra           8.653750  55.710000  39.816667  29.041667  109.490000
# ...                    ...        ...        ...        ...         ...
# Venezuela         6.795809  41.480000  36.230000  14.173235   63.297059
# Vietnam           3.815263  55.663158   8.408571  10.524737   59.386842
# Yemen             6.881600  85.812000  54.960000  82.755000  131.288000
# Zambia            3.802500  44.405000  38.640000   4.727500  244.430000
# Zimbabwe          7.261295  54.820000  30.000000   9.718750  158.190000
#
#                  childcare   clothing         rent  housing_price  \
# country
# ...

# %%
# replacing the NaN values with the mean of every country column

for col in cost.columns:
    cost[col] = cost.apply(lambda row: row[col] if pd.notnull(row[col]) and row[col] != 0.00 else country_means.loc[row['country'], col], axis=1)

# %%
# checking for NaN

cost.isna().sum()
# Out:
# city               0
# country            0
# restaurant         0
# groceries          0
# transport         27
# freetime           6
# utilities          0
# childcare         22
# clothing          10
# rent               1
# housing_price     20
# average_salary     6
# dtype: int64

# %%
cost
# Out:
#                     city      country  restaurant  groceries  transport  \
# 0                  Delhi        India    4.897500      36.63  11.630000
# 1               Shanghai        China    7.725000      71.51  27.940000
# 2                Jakarta    Indonesia    4.567500      62.00   9.530000
# 3                 Manila  Philippines    5.246250      46.84  11.860000
# 4                  Seoul  South Korea    9.950000     127.80  41.470000
# ...                  ...          ...         ...        ...        ...
# 4864        Port Douglas    Australia   13.796250     100.61  78.006400
# 4865         Rockhampton    Australia   12.638750      68.43  90.530000
# 4867        Egilsstadhir      Iceland   13.910000      91.46  52.960000
# 4871  Ixtapa Zihuatanejo       Mexico    7.591429       4.63  19.720943
# 4872             Iqaluit       Canada   18.143750      98.29  66.037111
#
#       freetime  utilities    childcare   clothing         rent  housing_price  \
# ...

# %%
# drop the last NaN values

cost.dropna(inplace=True)

# %%
cost.isnull().sum()
# Out:
# city              0
# country           0
# restaurant        0
# groceries         0
# transport         0
# freetime          0
# utilities         0
# childcare         0
# clothing          0
# rent              0
# housing_price     0
# average_salary    0
# dtype: int64

# %%
cost
# Out:
#                     city      country  restaurant  groceries  transport  \
# 0                  Delhi        India    4.897500      36.63  11.630000
# 1               Shanghai        China    7.725000      71.51  27.940000
# 2                Jakarta    Indonesia    4.567500      62.00   9.530000
# 3                 Manila  Philippines    5.246250      46.84  11.860000
# 4                  Seoul  South Korea    9.950000     127.80  41.470000
# ...                  ...          ...         ...        ...        ...
# 4864        Port Douglas    Australia   13.796250     100.61  78.006400
# 4865         Rockhampton    Australia   12.638750      68.43  90.530000
# 4867        Egilsstadhir      Iceland   13.910000      91.46  52.960000
# 4871  Ixtapa Zihuatanejo       Mexico    7.591429       4.63  19.720943
# 4872             Iqaluit       Canada   18.143750      98.29  66.037111
#
#       freetime  utilities    childcare   clothing         rent  housing_price  \
# ...

# %%
# Finally having Zero NaN

cost.isnull().sum()
# Out:
# city              0
# country           0
# restaurant        0
# groceries         0
# transport         0
# freetime          0
# utilities         0
# childcare         0
# clothing          0
# rent              0
# housing_price     0
# average_salary    0
# dtype: int64

# %%
# round the values on the clean df

cost = cost.round(2)

# %%
cost
# Out:
#                     city      country  restaurant  groceries  transport  \
# 0                  Delhi        India        4.90      36.63      11.63
# 1               Shanghai        China        7.72      71.51      27.94
# 2                Jakarta    Indonesia        4.57      62.00       9.53
# 3                 Manila  Philippines        5.25      46.84      11.86
# 4                  Seoul  South Korea        9.95     127.80      41.47
# ...                  ...          ...         ...        ...        ...
# 4864        Port Douglas    Australia       13.80     100.61      78.01
# 4865         Rockhampton    Australia       12.64      68.43      90.53
# 4867        Egilsstadhir      Iceland       13.91      91.46      52.96
# 4871  Ixtapa Zihuatanejo       Mexico        7.59       4.63      19.72
# 4872             Iqaluit       Canada       18.14      98.29      66.04
#
#       freetime  utilities  childcare  clothing     rent  housing_price  \
# ...

# %%
# to convert countries to continent


from country_converter import CountryConverter

# %%
# creating a new column for the continents

cc = CountryConverter()
cost['continent'] = cost['country'].apply(cc.convert, to='continent')

# %%
# reordering the columns 

new_column_order = ['city', 'country', 'continent', 'restaurant', 'groceries', 'transport', 'freetime', 'utilities', 'childcare', 'clothing', 'rent', 'housing_price', 'average_salary']
cost = cost[new_column_order]

# %%
cost
# Out:
#                     city      country continent  restaurant  groceries  \
# 0                  Delhi        India      Asia        4.90      36.63
# 1               Shanghai        China      Asia        7.72      71.51
# 2                Jakarta    Indonesia      Asia        4.57      62.00
# 3                 Manila  Philippines      Asia        5.25      46.84
# 4                  Seoul  South Korea      Asia        9.95     127.80
# ...                  ...          ...       ...         ...        ...
# 4864        Port Douglas    Australia   Oceania       13.80     100.61
# 4865         Rockhampton    Australia   Oceania       12.64      68.43
# 4867        Egilsstadhir      Iceland    Europe       13.91      91.46
# 4871  Ixtapa Zihuatanejo       Mexico   America        7.59       4.63
# 4872             Iqaluit       Canada   America       18.14      98.29
#
#       transport  freetime  utilities  childcare  clothing     rent  \
# ...

# %%
######### Used to check some info from the data #########

# %%
average_salary_us = cost.loc[cost['country'] == 'United States', 'average_salary']

# %%
average_salary_us.mean().round(2)
# Out:
# 3987.55

# %%
cost.describe().round(2)
# Out:
#        restaurant  groceries  transport  freetime  utilities  childcare  \
# count     4650.00    4650.00    4650.00   4650.00    4650.00    4650.00
# mean         9.08      58.36      43.47     19.54     167.56     538.14
# std          5.24      26.79      31.77     12.25      98.77     514.23
# min          0.84       0.66       0.00      0.81       2.44       4.07
# 25%          4.83      38.29      20.00     10.72      84.78     155.80
# 50%          8.42      54.68      37.75     18.12     161.76     332.38
# 75%         12.62      75.78      62.25     25.06     230.66     888.78
# max         80.00     216.79     364.58    131.72    1401.95    4250.00
#
#        clothing      rent  housing_price  average_salary
# count   4650.00   4650.00        4650.00         4650.00
# mean      62.23    878.91        2790.87         1909.62
# std       23.62    760.50        3606.27         1622.20
# min        8.03     19.66          84.14           18.00
# ...

# %%
upper_filter = cost['rent'].mean()+3*cost['rent'].std()

# %%
# Serching for outliers:

# Q1 = np.percentile(metabolic_df['BMI'], 25, method='midpoint')
# Q3 = np.percentile(metabolic_df['BMI'], 75, method='midpoint')
# IQR = Q3 - Q1
# print(IQR)

#bmi_filtered = metabolic_df['BMI'].std()

upper_filter = cost['rent'].mean()+3*cost['rent'].std()
lower_filter = cost['rent'].mean()-3*cost['rent'].std()

rent_filtered = cost[(cost['rent']  < upper_filter) & (cost['rent']  > lower_filter)]

cost_filtered = rent_filtered
rent_filtered
# Out:
#                     city      country continent  restaurant  groceries  \
# 0                  Delhi        India      Asia        4.90      36.63
# 1               Shanghai        China      Asia        7.72      71.51
# 2                Jakarta    Indonesia      Asia        4.57      62.00
# 3                 Manila  Philippines      Asia        5.25      46.84
# 4                  Seoul  South Korea      Asia        9.95     127.80
# ...                  ...          ...       ...         ...        ...
# 4864        Port Douglas    Australia   Oceania       13.80     100.61
# 4865         Rockhampton    Australia   Oceania       12.64      68.43
# 4867        Egilsstadhir      Iceland    Europe       13.91      91.46
# 4871  Ixtapa Zihuatanejo       Mexico   America        7.59       4.63
# 4872             Iqaluit       Canada   America       18.14      98.29
#
#       transport  freetime  utilities  childcare  clothing     rent  \
# ...

# %%
# Checking for Outliers



def filter_outliers(df, column, multiplier=3):
    upper_filter = df[column].mean() + multiplier * df[column].std()
    lower_filter = df[column].mean() - multiplier * df[column].std()
    return df[(df[column] < upper_filter) & (df[column] > lower_filter)]


numeric_columns = ['restaurant', 'groceries', 'transport', 'freetime', 'utilities', 'childcare', 'clothing', 'rent', 'housing_price', 'average_salary']


cost_filtered = cost.copy() 

for column in numeric_columns:
    cost_filtered_1 = filter_outliers(cost_filtered, column)

# %%
cost.describe()
# Out:
#         restaurant    groceries    transport     freetime    utilities  \
# count  4650.000000  4650.000000  4650.000000  4650.000000  4650.000000
# mean      9.077731    58.355398    43.471372    19.542396   167.555568
# std       5.235525    26.785938    31.770077    12.248845    98.765852
# min       0.840000     0.660000     0.000000     0.810000     2.440000
# 25%       4.830000    38.292500    20.000000    10.720000    84.780000
# 50%       8.420000    54.675000    37.750000    18.120000   161.765000
# 75%      12.620000    75.785000    62.250000    25.060000   230.655000
# max      80.000000   216.790000   364.580000   131.720000  1401.950000
#
#          childcare     clothing          rent  housing_price  average_salary
# count  4650.000000  4650.000000   4650.000000    4650.000000     4650.000000
# mean    538.142757    62.230991    878.908183    2790.874245     1909.621619
# std     514.227549    23.618648    760.503519    3606.271719     1622.196034
# ...

# %%
def filter_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_filter = Q1 - 1.5 * IQR
    upper_filter = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_filter) & (df[column] <= upper_filter)]

# List of numeric columns to filter
numeric_columns = ['restaurant', 'groceries', 'transport', 'freetime', 'utilities', 'childcare', 'clothing', 'rent', 'housing_price', 'average_salary']

# Apply the filter_outliers_iqr function to all numeric columns
cost_filtered = cost.copy()  # Create a copy of the original DataFrame

for column in numeric_columns:
    cost_filtered_2 = filter_outliers_iqr(cost_filtered, column)

    
cost_filtered_2.describe().round(2)
# Out:
#        restaurant  groceries  transport  freetime  utilities  childcare  \
# count     4615.00    4615.00    4615.00   4615.00    4615.00    4615.00
# mean         9.02      58.04      43.23     19.45     167.08     531.23
# std          5.20      26.49      31.68     12.16      98.82     505.34
# min          0.84       0.66       0.00      0.81       2.44       4.07
# 25%          4.80      38.18      20.00     10.66      84.60     155.67
# 50%          8.32      54.44      37.70     18.05     160.99     331.19
# 75%         12.59      75.37      62.25     25.00     230.00     874.36
# max         80.00     209.17     364.58    131.72    1401.95    4250.00
#
#        clothing      rent  housing_price  average_salary
# count   4615.00   4615.00        4615.00         4615.00
# mean      62.14    866.44        2773.53         1864.80
# std       23.63    745.43        3599.99         1541.67
# min        8.03     19.66          84.14           18.00
# ...

# %%
cost_filtered_2
# Out:
#                     city      country continent  restaurant  groceries  \
# 0                  Delhi        India      Asia        4.90      36.63
# 1               Shanghai        China      Asia        7.72      71.51
# 2                Jakarta    Indonesia      Asia        4.57      62.00
# 3                 Manila  Philippines      Asia        5.25      46.84
# 4                  Seoul  South Korea      Asia        9.95     127.80
# ...                  ...          ...       ...         ...        ...
# 4864        Port Douglas    Australia   Oceania       13.80     100.61
# 4865         Rockhampton    Australia   Oceania       12.64      68.43
# 4867        Egilsstadhir      Iceland    Europe       13.91      91.46
# 4871  Ixtapa Zihuatanejo       Mexico   America        7.59       4.63
# 4872             Iqaluit       Canada   America       18.14      98.29
#
#       transport  freetime  utilities  childcare  clothing     rent  \
# ...

# %%
cost.describe().round(2)
# Out:
#        restaurant  groceries  transport  freetime  utilities  childcare  \
# count     4650.00    4650.00    4650.00   4650.00    4650.00    4650.00
# mean         9.08      58.36      43.47     19.54     167.56     538.14
# std          5.24      26.79      31.77     12.25      98.77     514.23
# min          0.84       0.66       0.00      0.81       2.44       4.07
# 25%          4.83      38.29      20.00     10.72      84.78     155.80
# 50%          8.42      54.68      37.75     18.12     161.76     332.38
# 75%         12.62      75.78      62.25     25.06     230.66     888.78
# max         80.00     216.79     364.58    131.72    1401.95    4250.00
#
#        clothing      rent  housing_price  average_salary
# count   4650.00   4650.00        4650.00         4650.00
# mean      62.23    878.91        2790.87         1909.62
# std       23.62    760.50        3606.27         1622.20
# min        8.03     19.66          84.14           18.00
# ...

# %%
cost_filtered_2.describe().round(2)
# Out:
#        restaurant  groceries  transport  freetime  utilities  childcare  \
# count     4615.00    4615.00    4615.00   4615.00    4615.00    4615.00
# mean         9.02      58.04      43.23     19.45     167.08     531.23
# std          5.20      26.49      31.68     12.16      98.82     505.34
# min          0.84       0.66       0.00      0.81       2.44       4.07
# 25%          4.80      38.18      20.00     10.66      84.60     155.67
# 50%          8.32      54.44      37.70     18.05     160.99     331.19
# 75%         12.59      75.37      62.25     25.00     230.00     874.36
# max         80.00     209.17     364.58    131.72    1401.95    4250.00
#
#        clothing      rent  housing_price  average_salary
# count   4615.00   4615.00        4615.00         4615.00
# mean      62.14    866.44        2773.53         1864.80
# std       23.63    745.43        3599.99         1541.67
# min        8.03     19.66          84.14           18.00
# ...

# %%
def identify_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_filter = Q1 - 1.5 * IQR
    upper_filter = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower_filter) | (df[column] > upper_filter)]
    
    if not outliers.empty:
        print(f"Extreme values found in column {column}:")
        print(outliers[[column]])
        print("\n")
    
    return outliers

# List of numeric columns to check for outliers
numeric_columns = ['restaurant', 'groceries', 'transport', 'freetime', 'utilities', 'childcare', 'clothing', 'rent', 'housing_price', 'average_salary']

# Identify outliers in all numeric columns
outliers_found = pd.DataFrame()
for column in numeric_columns:
    outliers_found = pd.concat([outliers_found, identify_outliers(cost, column)], axis=1)

# Display the resulting DataFrame with identified outliers
print(outliers_found)
# Out:
# Extreme values found in column restaurant:
#       restaurant
# 529        28.00
# 535        26.38
# 907        24.67
# 965        24.80
# 1016       33.14
# 1540       51.00
# 1596       24.62
# 1767       24.87
# 2495       26.54
# 2623       24.42
# 2823       80.00
# 2974       25.87
# 3092       25.17
# 3175       24.40
# 3218       34.08
# 3320       54.27
# 3375       31.60
# 3777       28.00
# 4082       27.25
# 4138       26.38
# 4309       24.85
# 4322       24.44
# 4511       24.67
# 4603       25.42
# 4621       34.26
# 4625       26.15
# 4631       75.00
# 4677       28.67
# 4681       24.59
# 4735       24.46
# 4811       27.70
# 4819       24.46
#
#
# Extreme values found in column groceries:
#       groceries
# 374      134.87
# 433      197.02
# 507      162.65
# 529      181.90
# 625      148.50
# 965      163.81
# 985      135.85
# 1596     139.88
# 1767     183.02
# 1883     146.62
# 2087     166.35
# 2405     142.22
# 2623     172.97
# 2789     139.69
# ...

# %%
row_to_remove = cost[(cost['city'] == 'Niamey') & (cost['housing_price'] == 158348.36)]

# Remove the identified row from the DataFrame
cost = cost.drop(row_to_remove.index)

# %%
cost.describe().round(2)
# Out:
#        restaurant  groceries  transport  freetime  utilities  childcare  \
# count     4649.00    4649.00    4649.00   4649.00    4649.00    4649.00
# mean         9.08      58.36      43.48     19.54     167.51     538.07
# std          5.24      26.79      31.77     12.25      98.73     514.26
# min          0.84       0.66       0.00      0.81       2.44       4.07
# 25%          4.83      38.29      20.00     10.72      84.78     155.80
# 50%          8.43      54.67      37.75     18.12     161.67     332.38
# 75%         12.62      75.79      62.25     25.06     230.64     888.78
# max         80.00     216.79     364.58    131.72    1401.95    4250.00
#
#        clothing      rent  housing_price  average_salary
# count   4649.00   4649.00        4649.00         4649.00
# mean      62.24    878.99        2757.41         1909.99
# std       23.62    760.56        2792.98         1622.18
# min        8.03     19.66          84.14           18.00
# ...

# %%
cost.reset_index(drop=True, inplace=True)

# %%
cost
# Out:
#                     city      country continent  restaurant  groceries  \
# 0                  Delhi        India      Asia        4.90      36.63
# 1               Shanghai        China      Asia        7.72      71.51
# 2                Jakarta    Indonesia      Asia        4.57      62.00
# 3                 Manila  Philippines      Asia        5.25      46.84
# 4                  Seoul  South Korea      Asia        9.95     127.80
# ...                  ...          ...       ...         ...        ...
# 4644        Port Douglas    Australia   Oceania       13.80     100.61
# 4645         Rockhampton    Australia   Oceania       12.64      68.43
# 4646        Egilsstadhir      Iceland    Europe       13.91      91.46
# 4647  Ixtapa Zihuatanejo       Mexico   America        7.59       4.63
# 4648             Iqaluit       Canada   America       18.14      98.29
#
#       transport  freetime  utilities  childcare  clothing     rent  \
# ...

# %%
#Export the clean file

cost.to_csv('cost_clean.csv', index=False)
